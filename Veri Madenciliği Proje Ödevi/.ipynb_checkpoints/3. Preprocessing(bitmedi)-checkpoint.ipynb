# %%
import pandas as pd
import numpy as np
import pandas_profiling

# %%
dataset = pd.read_csv("C:\\Users\\HP\\Desktop\\4.sınıf Güz Dönemi\\Profesyonel Yazılım Geliştirme\\Profesyonel Yazılım Geliştirme 2\\Makine Öğrenmesi LAB3\\phones.csv")

# %%
dataset = pd.read_csv("shoes_trendyol_data.csv")

# %%
dataset
# Out:
#                                              Unnamed: 0 Astar Materyali  \
# 0                                                   NaN             NaN
# 1                                                   NaN         Tekstil
# 2                                                   NaN             NaN
# 3                                                   NaN         Tekstil
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 1411                                                NaN             NaN
# 1412                                                NaN         Tekstil
# 1413                                                NaN             NaN
# 1414                                                NaN             NaN
# 1415  • Silerek temizleyebilirsiniz • Detaylı bakım ...       Suni Deri
#
#      Ayakkabı Tabanı Bağlama Şekli     Bilek Stili Boy / Ölçü   Deri Kalitesi  \
# ...

# %%
s
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14640\2594721444.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataset["price"] = dataset.price.str.replace('.', '')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 15>()
#      13 dataset["price"] = dataset.price.str.replace(',09'.format(i), '')
#      14 dataset["price"] = dataset.price.str.replace('.', '')
# ---> 15 dataset["price"] = dataset.price.astype(float)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
# ...

# %%
dataset["Renk"]
# Out:
# 0          Siyah
# 1          Siyah
# 2          Siyah
# 3          Siyah
# 4          Siyah
#           ...
# 1411         Gri
# 1412         Gri
# 1413        Mavi
# 1414       Siyah
# 1415    Lacivert
# Name: Renk, Length: 1416, dtype: object

# %%
dataset["Ayakkabı Tabanı"].dropna()
# Out:
# 80      Outdoor
# 738      Indoor
# 805      Indoor
# 849     Outdoor
# 1075    Outdoor
# Name: Ayakkabı Tabanı, dtype: object

# %%
dataset["Ayakkabı Tabanı"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1411    NaN
# 1412    NaN
# 1413    NaN
# 1414    NaN
# 1415    NaN
# Name: Ayakkabı Tabanı, Length: 1416, dtype: object

# %%
import pandas as pd
import numpy as np
import pandas_profiling

# %%
dataset = pd.read_csv("C:\\Users\\HP\\Desktop\\4.sınıf Güz Dönemi\\Veri Madenciliği\\Veri Madenciliği Proje Ödevi\\2Shoes_EDA_sonrası.csv")

# %%
dataset
# Out:
#                                              Unnamed: 0 Astar Materyali  \
# 0                                                   NaN             NaN
# 1                                                   NaN         Tekstil
# 2                                                   NaN             NaN
# 3                                                   NaN         Tekstil
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 1411                                                NaN             NaN
# 1412                                                NaN         Tekstil
# 1413                                                NaN             NaN
# 1414                                                NaN             NaN
# 1415  • Silerek temizleyebilirsiniz • Detaylı bakım ...       Suni Deri
#
#      Bağlama Şekli     Desen Dış Materyal               Ek Özellik  \
# ...

# %%
# Aşağıda veri ön işlemede label encoder ve one hot encoder yapılacak kolonlar tespit edilecektir
# Ön işleme ile kategorik veriler sayısallaştırılacak

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Astar Materyali', 'Bağlama Şekli', 'Desen',
#        'Dış Materyal', 'Ek Özellik', 'Kullanım Alanı', 'Kumaş Tipi',
#        'Materyal', 'Materyal Bileşeni', 'Ortam', 'Persona', 'Renk',
#        'Saya Materyali', 'Taban Materyali', 'Taban Teknolojisi', 'Taban Tipi',
#        'Topuk Boyu', 'Topuk Tipi', 'İç Taban Materyali', 'url', 'price'],
#       dtype='object')

# %%
#Bu öznitelik kolonunda 2 çeşit değer vardır. Bu kolonda label encoder uygulanabilir.
dataset["Unnamed: 0"].value_counts()
# Out:
# • Silerek temizleyebilirsiniz • Detaylı bakım talimatları için lütfen ürün etiketini kontrol ediniz.    208
# • Detaylı bakım talimatları için lütfen ürün etiketini kontrol ediniz.                                    6
# Name: Unnamed: 0, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
dataset["Unnamed: 0"] = lb.fit_transform(dataset["Unnamed: 0"])

# %%
#Bu öznitelik kolonunda 3 çeşit değer vardır. One hot encoder denenmeli ancak label encoder da denenebilir.
dataset["Astar Materyali"].value_counts()
# Out:
# Tekstil        240
# Suni Deri       96
# Hakiki Deri     56
# Name: Astar Materyali, dtype: int64

# %%
lb = LabelEncoder()
dataset["Astar Materyali"] = lb.fit_transform(dataset["Astar Materyali"])

# %%
# Bu kolondaki Banlı değerleri, Slip-on değerleri ve Lastikli değerleri sayıca az olduğu için datasetten atıldı.
dataset["Bağlama Şekli"].value_counts()
# Out:
# Bağcıklı     755
# Bağcıksız     99
# Fermuarlı     46
# Bantlı        15
# Slip-on        6
# Lastikli       6
# Name: Bağlama Şekli, dtype: int64

# %%
dataset.set_index("Bağlama Şekli",inplace=True)

# %%
dataset.drop("Bantlı",inplace=True)
dataset.drop("Slip-on",inplace=True)
dataset.drop("Lastikli",inplace=True)

# %%
dataset.reset_index(inplace= True)

# %%
dataset
# Out:
#      Bağlama Şekli  Unnamed: 0  Astar Materyali     Desen Dış Materyal  \
# 0        Bağcıksız           2                3       NaN          NaN
# 1         Bağcıklı           2                2       NaN          NaN
# 2              NaN           2                3       NaN          NaN
# 3              NaN           2                2       NaN          NaN
# 4              NaN           2                3       NaN          NaN
# ...            ...         ...              ...       ...          ...
# 1384           NaN           2                3       NaN          NaN
# 1385      Bağcıklı           2                2  Düz Renk      Tekstil
# 1386           NaN           2                3       NaN          NaN
# 1387     Fermuarlı           2                3       NaN    Suni Deri
# 1388      Bağcıklı           1                1       Düz          NaN
#
#                    Ek Özellik Kullanım Alanı Kumaş Tipi   Materyal  \
# ...

# %%
#Bağlama Şekli feature'onda alan value çeşidi sayısı 3'e düşürüldü. Burada da label encoder denenebilir.
lb = LabelEncoder()
dataset["Bağlama Şekli"] = lb.fit_transform(dataset["Bağlama Şekli"])

# %%
# Bu kolondaki sayıca az değerler atıldı.
dataset["Desen"].value_counts()
# Out:
# Düz               212
# Renk Bloklu        53
# Düz Renk           21
# Slogan             14
# Desensiz           10
# Hayvan Desenli      6
# Yazılı              4
# Desenli             4
# City                3
# Baskılı             3
# Zigzag              2
# Logolu              2
# Dokulu              2
# Çizgili             1
# Kamuflaj            1
# Mix                 1
# Peluş               1
# Name: Desen, dtype: int64

# %%
dataset.set_index("Desen",inplace=True)

# %%
dataset.drop(["Hayvan Desenli","Yazılı","Desenli","City","Baskılı","Zigzag","Logolu","Dokulu","Çizgili","Kamuflaj","Mix","Peluş"],inplace=True)

# %%
dataset.reset_index(inplace=True)

# %%
dataset
# Out:
#          Desen  Bağlama Şekli  Unnamed: 0  Astar Materyali Dış Materyal  \
# 0          NaN              1           2                3          NaN
# 1          NaN              0           2                2          NaN
# 2          NaN              3           2                3          NaN
# 3          NaN              3           2                2          NaN
# 4          NaN              3           2                3          NaN
# ...        ...            ...         ...              ...          ...
# 1354       NaN              3           2                3          NaN
# 1355  Düz Renk              0           2                2      Tekstil
# 1356       NaN              3           2                3          NaN
# 1357       NaN              2           2                3    Suni Deri
# 1358       Düz              0           1                1          NaN
#
#                    Ek Özellik Kullanım Alanı Kumaş Tipi   Materyal  \
# ...

# %%
Bu kısımDAN SONRASINDA KALDIM
# Out:
#   Input In [57]
#     Bu kısımDAN SONRASINDA KALDIM
#        ^
# SyntaxError: invalid syntax

# %%
#Desen kolonu one hot encode edilmeden önce shape'i (1359, ),den (1359,1) dönüştürüldü. Şimdi one hot encoder edilmeye uygun
dataset["Desen"] = dataset.iloc[:,0:1].values
dataset["Desen"].shape
# Out:
# (1359,)

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()
dataset["Desen"] = one.fit_transform(dataset["Desen"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [56], in <cell line: 3>()
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 one = OneHotEncoder()
# ----> 3 dataset["Desen"] = one.fit_transform(dataset["Desen"])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:488, in OneHotEncoder.fit_transform(self, X, y)
#     466 """
#     467 Fit OneHotEncoder to X, then transform X.
#     468
#    (...)
#     485     returned.
#     486 """
#     487 self._validate_keywords()
# --> 488 return super().fit_transform(X, y)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
# ...

# %%
dataset["Desen"].shape
# Out:
# (1359,)

# %%
X.shape
# Out:
# (1359, 1)

# %%
dataset
# Out:
#          Desen  Bağlama Şekli  Unnamed: 0  Astar Materyali Dış Materyal  \
# 0          NaN              1           2                3          NaN
# 1          NaN              0           2                2          NaN
# 2          NaN              3           2                3          NaN
# 3          NaN              3           2                2          NaN
# 4          NaN              3           2                3          NaN
# ...        ...            ...         ...              ...          ...
# 1354       NaN              3           2                3          NaN
# 1355  Düz Renk              0           2                2      Tekstil
# 1356       NaN              3           2                3          NaN
# 1357       NaN              2           2                3    Suni Deri
# 1358       Düz              0           1                1          NaN
#
#                    Ek Özellik Kullanım Alanı Kumaş Tipi   Materyal  \
# ...

# %%
Dış Materyal

# %%
Dış Materyal

# %%
Dış Materyal

# %%
Ek Özellik

# %%
Ek Özellik

# %%
Ek Özellik

# %%
Kullanım Alanı

# %%
Kullanım Alanı

# %%
Kullanım Alanı

# %%
Kumaş Tipi

# %%
Kumaş Tipi

# %%
Kumaş Tipi

# %%
Materyal

# %%
Materyal

# %%
Materyal

# %%
Bileşeni

# %%
Bileşeni

# %%
Bileşeni

# %%
Ortam

# %%
Ortam

# %%
Ortam

# %%
Persona

# %%
Persona

# %%
Persona

# %%
Renk

# %%
Renk

# %%
Renk

# %%
Saya Materyali

# %%
Saya Materyali

# %%
Saya Materyali

# %%
Taban Materyali

# %%
Taban Materyali

# %%
Taban Materyali

# %%
Taban Teknolojisi

# %%
Taban Teknolojisi

# %%
Taban Teknolojisi

# %%
Taban Tipi

# %%
Taban Tipi

# %%
Taban Tipi

# %%
Topuk Boyu

# %%
Topuk Boyu

# %%
Topuk Boyu

# %%
Topuk Tipi

# %%
Topuk Tipi

# %%
Topuk Tipi

# %%
İç Taban Materyali

# %%
İç Taban Materyali

# %%
İç Taban Materyali

# %%
'Saya Materyali', 'Taban Materyali', 'Taban Teknolojisi', 'Taban Tipi',
       'Topuk Boyu', 'Topuk Tipi', 'İç Taban Materyali', 'url', 'price']
